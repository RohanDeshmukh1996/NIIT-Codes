# %%
import pandas as pd
data=pd.read_csv("DS1_C4_S4_Used_Car_Prices_Data_Challenge.csv")
data
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission state  condition  odometer   color interior  \
# 0         automatic    ca        5.0   16639.0   white    black
# ...

# %%
# Task 1
print(data.isnull().sum())
#Using dropna to remove all the rows who have null values by using inplace 
data.dropna(inplace=True)
data.isnull().sum()
# Out:
# year                0
# make            10301
# model           10399
# trim            10651
# body            13195
# transmission    65353
# state               1
# condition       11794
# odometer           94
# color             749
# interior          749
# seller              0
# mp                  0
# Arrival_Date       25
# dtype: int64
# year            0
# make            0
# model           0
# trim            0
# body            0
# transmission    0
# state           0
# condition       0
# odometer        0
# color           0
# interior        0
# seller          0
# mp              0
# Arrival_Date    0
# dtype: int64

# %%
# Task 2
# giving condition and sorting the values acending and only saving top 100 in new dataframe
x=data[(data.year==2014)&(data.state=="ca")].sort_values("mp").head(100)
x
# Out:
#         year        make       model           trim       body transmission  \
# 179673  2014      Nissan       Versa         1.6 SV      Sedan    automatic
# 494101  2014  Mitsubishi      Mirage             DE  hatchback    automatic
# 477609  2014      Nissan       Versa         1.6 SV      sedan    automatic
# 444039  2014      Nissan       Versa         1.6 SV      Sedan       manual
# 543536  2014       smart      fortwo  passion coupe  hatchback    automatic
# ...      ...         ...         ...            ...        ...          ...
# 120118  2014  Mitsubishi      Lancer             ES      Sedan    automatic
# 408827  2014      Nissan  Versa Note         1.6 SV  Hatchback       manual
# 197057  2014      Nissan       Versa         1.6 SV      Sedan    automatic
# 299017  2014      Nissan       Versa         1.6 SV      Sedan    automatic
# 197093  2014      Nissan       Versa         1.6 SV      Sedan    automatic
#
#        state  condition  odometer   color interior  \
# ...

# %%
#Task 3
# using groupby made groub of make column and used mesn on mp column
x.groupby('make')['mp'].mean()
# Out:
# make
# Chevrolet     9255.000000
# FIAT          9150.000000
# Ford          9292.857143
# Hyundai       9675.000000
# Mazda         9475.000000
# Mitsubishi    8866.666667
# Nissan        9124.537037
# Toyota        9637.500000
# Volkswagen    9175.000000
# smart         9200.000000
# Name: mp, dtype: float64

# %%
# Task 4
# using condition on dataframe and storing it in new data frame
y=x[x.make=="Chevrolet"]
# adding new column in new dataframe in which discount value is shown
y['discount_price']=y.mp-(y.mp*0.1)
y
# Out:
# C:\Users\imlad\AppData\Local\Temp\ipykernel_26212\1630135673.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y['discount_price']=y.mp-(y.mp*0.1)
#         year       make  model trim       body transmission state  condition  \
# 518957  2014  Chevrolet  Spark  1LT  hatchback    automatic    ca        1.0
# 473427  2014  Chevrolet  Spark  1LT  hatchback    automatic    ca        2.3
# 80892   2014  Chevrolet  Spark  1LT  Hatchback    automatic    ca        2.0
# 44314   2014  Chevrolet  Spark  1LT  Hatchback    automatic    ca        2.0
# 531030  2014  Chevrolet  Sonic   LT      sedan    automatic    ca        2.5
# 258946  2014  Chevrolet  Sonic   LS  Hatchback       manual    ca        1.9
# ...

# %%
# Task 5
# using pivot table  fro interior color and men function on mp
x.pivot_table("mp","interior",aggfunc=['mean'])
# Out:
#                  mean
#                    mp
# interior
# beige     9600.000000
# black     9128.525641
# gray      9314.285714
# red       9150.000000
# tan       9575.000000
# —         9437.500000

# %% [markdown]
# ### only beige color mp value is higher than black and grey and rest are lower

# %%
# Task 6
# giving condiition and storing it in new data frame
y=data[(data.year>=2010)&(data.year<=2015)]
# using groupby on new dataframe  for make, color and count on color for values
y.groupby(['make','color'])['color'].count()
# Out:
# make   color
# Acura  beige         1
#        black       675
#        blue         64
#        brown         8
#        burgundy     69
#                   ...
# smart  red          37
#        silver       46
#        white        65
#        yellow        4
#        —             8
# Name: color, Length: 620, dtype: int64

# %%
# Task 7
# giving condiition and storing it in new data frame
y=data[(data.make=="BMW")&((data.body=="Sedan")|(data.body=="sedan"))&(data.year>=2010)&(data.year<=2015)
     &(data.condition>=4.5)]
# using pivot table on new dataframe  for year, model and max on mp for values
y.pivot_table(index=['year','model'],values=['mp'], aggfunc='max')
# Out:
#                               mp
# year model
# 2010 3 Series              14600
#      5 Series              23200
#      7 Series              28100
# 2011 3 Series              38500
#      5 Series              37000
#      7 Series              26800
#      M3                    39700
# 2012 3 Series              33300
#      5 Series              44200
#      7 Series              43000
#      ActiveHybrid 7        34600
# 2013 3 Series              38300
#      5 Series              42300
#      6 Series Gran Coupe   63000
#      7 Series              61000
#      M5                    66000
# 2014 3 Series              44800
#      5 Series              65000
#      6 Series Gran Coupe   68000
#      7 Series              56200
#      ActiveHybrid 7        66000
#      M5                    78000
#      M6 Gran Coupe        105000
# 2015 3 Series              70000
#      4 Series Gran Coupe   46900
#      5 Series              61000
#      6 Series Gran Coupe   68000
# ...

# %%
# Task 8
# giving condiition and displaying it
data[(data.body=="SUV")&(data.year>=2010)&(data.year<=2015)&(data.odometer<=30000)].sort_values(ascending=False,by="odometer").head(100)
# Out:
#         year        make    model                trim body transmission state  \
# 338070  2012        Ford     Edge                 SEL  SUV    automatic    ca
# 113225  2012  Volkswagen   Tiguan                  SE  SUV    automatic    oh
# 408186  2012      Nissan   Murano                   S  SUV    automatic    tn
# 348586  2013       Acura      MDX  Technology Package  SUV    automatic    fl
# 147682  2012        Ford   Escape                 XLT  SUV    automatic    tn
# ...      ...         ...      ...                 ...  ...          ...   ...
# 283695  2013     Lincoln      MKX                Base  SUV    automatic    tn
# 220976  2012        Ford   Escape                 XLT  SUV    automatic    nj
# 249601  2012        Ford     Edge                 SEL  SUV    automatic    ca
# 206862  2013         Kia  Sorento                  LX  SUV    automatic    ca
# 415471  2014     Hyundai   Tucson                  SE  SUV    automatic    ca
#
# ...
