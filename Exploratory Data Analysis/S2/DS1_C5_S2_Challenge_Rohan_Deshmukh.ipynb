# %%
import matplotlib.pyplot as plt             # to visualize
from tabulate import tabulate               # to print the table
import matplotlib as mat                    # to visualize 
import seaborn as sns                       # to visualize
import pandas as pd                         # for data reading
import numpy as np                          # for numerical computation

# %%
df = pd.read_excel('DS1_C5_S2_Income_Data_Challenge.xlsx')
df
# Out:
#        Age   WorkClass    Education  Education_Num       Marital_Status  \
# 0       39   State-gov    Bachelors             13        Never-married
# 1       50    Self-emp    Bachelors             13   Married-civ-spouse
# 2       38     Private      HS-grad              9             Divorced
# 3       53     Private         11th              7   Married-civ-spouse
# 4       28     Private    Bachelors             13   Married-civ-spouse
# ...    ...         ...          ...            ...                  ...
# 32556   27     Private   Assoc-acdm             12   Married-civ-spouse
# 32557   40     Private      HS-grad              9   Married-civ-spouse
# 32558   58     Private      HS-grad              9              Widowed
# 32559   22     Private      HS-grad              9        Never-married
# 32560   52    Self-emp      HS-grad              9   Married-civ-spouse
#
#                Occupation    Relationship   Gender  Hours_Per_Week  \
# ...

# %%
l=list(df.columns)
for i in range(len(l)):
    print(l[i])
    print(df[l[i]].unique())
    print()
# Out:
# Age
# [39 50 38 53 28 37 49 52 31 42 30 23 32 40 34 25 43 54 35 59 56 19 20 45
#  22 48 21 24 57 44 41 29 18 47 46 36 79 27 67 33 76 17 55 61 70 64 71 68
#  66 51 58 26 60 90 75 65 77 62 63 80 72 74 69 73 81 78 88 82 83 84 85 86
#  87]
#
# WorkClass
# [' State-gov' 'Self-emp' ' Private' ' Federal-gov' ' Local-gov' ' ?'
#  ' Self-emp' ' Without-pay' ' Never-worked']
#
# Education
# [' Bachelors' ' HS-grad' ' 11th' ' Masters' ' 9th' ' Some-college'
#  ' Assoc-acdm' ' Assoc-voc' ' 7th-8th' ' Doctorate' ' Prof-school'
#  ' 5th-6th' ' 10th' ' 1st-4th' ' Preschool' ' 12th']
#
# Education_Num
# [13  9  7 14  5 10 12 11  4 16 15  3  6  2  1  8]
#
# Marital_Status
# [' Never-married' ' Married-civ-spouse' ' Divorced'
#  ' Married-spouse-absent' ' Separated' ' Married-AF-spouse' ' Widowed']
#
# Occupation
# [' Adm-clerical' ' Exec-managerial' ' Handlers-cleaners' ' Prof-specialty'
#  ' Other-service' ' Sales' ' Craft-repair' ' Transport-moving'
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32561 non-null  int64
#  1   WorkClass       32561 non-null  object
#  2   Education       32561 non-null  object
#  3   Education_Num   32561 non-null  int64
#  4   Marital_Status  32561 non-null  object
#  5   Occupation      32561 non-null  object
#  6   Relationship    32561 non-null  object
#  7   Gender          32561 non-null  object
#  8   Hours_Per_Week  32561 non-null  int64
#  9   Native_Country  32561 non-null  object
#  10  Income_Bracket  32561 non-null  object
# dtypes: int64(3), object(8)
# memory usage: 2.7+ MB

# %%
def col(df):
    x=df.select_dtypes(exclude='object')
    y=df.select_dtypes(include='object')
    x1=list(x.columns)
    y1=list(y.columns)
    return x1,y1


numerical,categorical=col(df)
print("Numerical")
print(numerical)
print("Categorical")
print(categorical)
# Out:
# Numerical
# ['Age', 'Education_Num', 'Hours_Per_Week']
# Categorical
# ['WorkClass', 'Education', 'Marital_Status', 'Occupation', 'Relationship', 'Gender', 'Native_Country', 'Income_Bracket']

# %%
# Task 1
def info_cat(c):
    for i in range(len(c)):
        print(f"Unique values in {c[i]} are :{df[c[i]].unique()}")
        print(f'The Mode of the col {c[i]} is  {df[c[i]].mode()[0]}')
        print()
        
def info_num(c):
    for i in range(len(c)):
        print(c[i])
        print(f'The Mean is : {df[c[i]].mean()}')
        print(f'The Median is : {df[c[i]].median()}')
        print(f'The STD is : {df[c[i]].std()}')
        print()
        
        
info_num(numerical)        
info_cat(categorical)
# Out:
# Age
# The Mean is : 38.58164675532078
# The Median is : 37.0
# The STD is : 13.640432553581146
#
# Education_Num
# The Mean is : 10.0806793403151
# The Median is : 10.0
# The STD is : 2.5727203320673406
#
# Hours_Per_Week
# The Mean is : 40.437455852092995
# The Median is : 40.0
# The STD is : 12.34742868173081
#
# Unique values in WorkClass are :[' State-gov' 'Self-emp' ' Private' ' Federal-gov' ' Local-gov' ' ?'
#  ' Self-emp' ' Without-pay' ' Never-worked']
# The Mode of the col WorkClass is   Private
#
# Unique values in Education are :[' Bachelors' ' HS-grad' ' 11th' ' Masters' ' 9th' ' Some-college'
#  ' Assoc-acdm' ' Assoc-voc' ' 7th-8th' ' Doctorate' ' Prof-school'
#  ' 5th-6th' ' 10th' ' 1st-4th' ' Preschool' ' 12th']
# The Mode of the col Education is   HS-grad
#
# Unique values in Marital_Status are :[' Never-married' ' Married-civ-spouse' ' Divorced'
#  ' Married-spouse-absent' ' Separated' ' Married-AF-spouse' ' Widowed']
# ...

# %%
# Task2

for i in range(len(categorical)):
    for j in range(i+1,len(categorical)):
        if categorical[i] != categorical[j]:
            print(categorical[i],"vs",categorical[j])
            plt.figure(figsize=(8,4))
            sns.countplot(y=categorical[i],hue=categorical[j],data=df)
            plt.show()
            print()
# Out:
# WorkClass vs Education
# WorkClass vs Marital_Status
# WorkClass vs Occupation
# WorkClass vs Relationship
# WorkClass vs Gender
# WorkClass vs Native_Country
# WorkClass vs Income_Bracket
# Education vs Marital_Status
# Education vs Occupation
# Education vs Relationship
# Education vs Gender
# Education vs Native_Country
# Education vs Income_Bracket
# Marital_Status vs Occupation
# Marital_Status vs Relationship
# Marital_Status vs Gender
# Marital_Status vs Native_Country
# Marital_Status vs Income_Bracket
# Occupation vs Relationship
# Occupation vs Gender
# Occupation vs Native_Country
# Occupation vs Income_Bracket
# Relationship vs Gender
# Relationship vs Native_Country
# Relationship vs Income_Bracket
# Gender vs Native_Country
# Gender vs Income_Bracket
# Native_Country vs Income_Bracket

# %%
# From abvo analysis we can say that:
# private workclass are hishest in private class have most Hs-grad,married-civ-spouse, adm-clerical, husband, male, US, <=50k income bracket
# Hs-grad have more in married-civ-spouse,sales,husband,male,US native,<50k bracket income
# married-civ-spouse have most adm-clerical,husband,male
# never married have most <k income bracket
# craft repar have most of husband relatonship,male
# adm-clerical have most <50k income bracket
# private work class have most male

# %%
# Task 3
for i in range(len(numerical)):
    for j in range(i+1,len(numerical)):
        if numerical[i] != numerical[j]:
            print(numerical[i],"vs",numerical[j])
            sns.histplot(x=df[numerical[i]],hue=df[numerical[j]])
            plt.show()
            print()
# Out:
# Age vs Education_Num
# Age vs Hours_Per_Week
# Education_Num vs Hours_Per_Week

# %%
# there are more people with age between 20-25 with education num 1
# there are more people with age between 25-30 with hour per week is 1 hour
# Education_num 9 have most people with per week hour
