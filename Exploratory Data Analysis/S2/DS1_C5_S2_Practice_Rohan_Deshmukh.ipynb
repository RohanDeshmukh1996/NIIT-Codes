# %%
import matplotlib.pyplot as plt             # to visualize
from tabulate import tabulate               # to print the table
import matplotlib as mat                    # to visualize 
import seaborn as sns                       # to visualize
import pandas as pd                         # for data reading
import numpy as np                          # for numerical computation

# %%
df = pd.read_csv("DS1_C5_S2_EmployeeAttrition_Data_Practice.csv")
l=list(df.columns)
for i in l:
    print(i)
# Out:
# Age
# Attrition
# BusinessTravel
# Department
# DistanceFromHome
# EducationField
# EmployeeNumber
# EnvironmentSatisfaction
# Gender
# HourlyRate
# JobInvolvement
# JobRole
# JobSatisfaction
# MaritalStatus
# MonthlyIncome
# NumCompaniesWorked
# Over18
# OverTime
# PerformanceRating
# RelationshipSatisfaction
# TotalWorkingYears
# TrainingTimesLastYear
# WorkLifeBalance
# YearsAtCompany
# YearsInCurrentRole
# YearsSinceLastPromotion
# YearsWithCurrManager

# %%
#Task 1.1
sns.countplot(x='BusinessTravel',hue='Attrition',data=df)
# Out:
# <Axes: xlabel='BusinessTravel', ylabel='count'>

# %%
# there are people who travel rarely whit both attrition

# %%
#Task 1.2
plt.figure(figsize=(12,4))
sns.countplot(x='EducationField',hue='Attrition',data=df)
# Out:
# <Axes: xlabel='EducationField', ylabel='count'>

# %%
# life science have highest no attrition

# %%
#Task 1.3
plt.figure(figsize=(12,4))
sns.countplot(x='Department',hue='Attrition',data=df)
# Out:
# <Axes: xlabel='Department', ylabel='count'>

# %%
# R&D have highet no attrition

# %%
#Task 1.4
plt.figure(figsize=(12,4))
sns.countplot(x='EnvironmentSatisfaction',hue='Attrition',data=df)
# Out:
# <Axes: xlabel='EnvironmentSatisfaction', ylabel='count'>

# %%
# Environment Staisfaction 4 and 3 have highet no attrition

# %%
#Task 1.5
plt.figure(figsize=(12,4))
sns.countplot(x='Gender',hue='Attrition',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
# male gender have highest no attrition

# %%
#Task 1.6
plt.figure(figsize=(12,4))
sns.countplot(x='MaritalStatus',hue='Attrition',data=df)
# Out:
# <Axes: xlabel='MaritalStatus', ylabel='count'>

# %%
# married marrtal status have highest no attrition

# %%
#Task 1.7
plt.figure(figsize=(12,4))
sns.countplot(x='PerformanceRating',hue='Attrition',data=df)
# Out:
# <Axes: xlabel='PerformanceRating', ylabel='count'>

# %%
# PerformanceRating 3 hve highest no attrition

# %%
#Task 1.8
plt.figure(figsize=(12,4))
sns.countplot(x='JobSatisfaction',hue='Attrition',data=df)
# Out:
# <Axes: xlabel='JobSatisfaction', ylabel='count'>

# %%
#JobSatisfaction 4 have highest no attrition

# %%
# Task 2.1
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
sns.histplot(x=df.Age,hue=df.Attrition)
plt.subplot(1,2,2)
sns.boxplot(x=df.Attrition,y=df.Age)
plt.show()

# %%
# there are no attrition highest at around 38-40 age

# %%
# Task 2.2
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
sns.histplot(x=df.HourlyRate,hue=df.Attrition)
plt.subplot(1,2,2)
sns.boxplot(x=df.Attrition,y=df.HourlyRate)
plt.show()

# %%
# Hourly rate are mostly similar to both  yes and no attrition

# %%
# Task 2.3
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
sns.histplot(x=df.MonthlyIncome,hue=df.Attrition)
plt.subplot(1,2,2)
sns.boxplot(x=df.Attrition,y=df.MonthlyIncome)
plt.show()

# %%
# 2500 monthly income have highest no attrition

# %%
# task 2.4
plt.figure(figsize=(10,8))
plt.subplot(2,1,1)
sns.histplot(x=df.DistanceFromHome,hue=df.Attrition)
plt.subplot(2,1,2)
sns.boxplot(y=df.Attrition,x=df.DistanceFromHome)
plt.show()

# %%
# people who have have to travel less have more no attrition

# %%
# task 2.5
plt.figure(figsize=(10,8))
plt.subplot(2,1,1)
sns.histplot(x=df.TotalWorkingYears,hue=df.Attrition)
plt.subplot(2,1,2)
sns.boxplot(y=df.Attrition,x=df.TotalWorkingYears)
plt.show()

# %%
# people who work for 5 and 10 year have highest no attrition

# %%
# Task 3
# condition to data frame and storing it new
df1=df[(df.BusinessTravel=="Travel_Rarely")&(df.Attrition=="No")]

sns.countplot(x='JobRole',hue='Attrition',data=df1, order =df1.JobRole.value_counts().index)
plt.show()

# %%
# sales Executive have highest no attrition

# %%
df2=df[(df.EducationField=='Medical')|(df.EducationField=='Life Sciences')]
sns.histplot(x=df2.Department,hue=df2.Attrition)
# Out:
# <Axes: xlabel='Department', ylabel='Count'>

# %%
# R&D department have highest no attrition

# %%
df4=df[(df.Department=='Sales')]
plt.figure(figsize=(12,4))
sns.countplot(x='Gender',hue='Attrition',data=df4)
plt.show()

# %%
# sales department male have highest yes and no attrition
