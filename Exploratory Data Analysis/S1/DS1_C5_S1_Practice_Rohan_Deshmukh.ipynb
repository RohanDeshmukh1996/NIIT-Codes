# %%
# Import all lib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df=pd.read_csv('DS1_C5_S1_EmployeeAttrition_Data_Practice.csv')
df[:5]
# Out:
#     Age Attrition     BusinessTravel              Department  \
# 0  41.0       Yes      Travel_Rarely                   Sales
# 1  49.0        No  Travel_Frequently  Research & Development
# 2  37.0       Yes      Travel_Rarely  Research & Development
# 3  33.0        No  Travel_Frequently  Research & Development
# 4  27.0        No      Travel_Rarely  Research & Development
#
#    DistanceFromHome EducationField  EmployeeNumber  EnvironmentSatisfaction  \
# 0                 1  Life Sciences               1                        2
# 1                 8  Life Sciences               2                        3
# 2                 2          Other               4                        4
# 3                 3  Life Sciences               5                        4
# 4                 2        Medical               7                        1
#
#    Gender  HourlyRate  ...  OverTime PerformanceRating  \
# 0  Female          94  ...       Yes                 3
# ...

# %%
# Task 1
# checking information about given data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1446 non-null   float64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1440 non-null   object
#  3   Department                1466 non-null   object
#  4   DistanceFromHome          1470 non-null   int64
#  5   EducationField            1458 non-null   object
#  6   EmployeeNumber            1470 non-null   int64
#  7   EnvironmentSatisfaction   1470 non-null   int64
#  8   Gender                    1425 non-null   object
#  9   HourlyRate                1470 non-null   int64
#  10  JobInvolvement            1470 non-null   int64
#  11  JobRole                   1460 non-null   object
#  12  JobSatisfaction           1470 non-null   int64
# ...

# %%
# Task2
#differentiating intocategorical and numerical values
def col(df):
    x=df.select_dtypes(exclude='object')
    y=df.select_dtypes(include='object')
    x1=list(x.columns)
    y1=list(y.columns)
    return x1,y1


numerical,categorical=col(df)
print(numerical)
print(categorical)
# Out:
# ['Age', 'DistanceFromHome', 'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobSatisfaction', 'MonthlyIncome', 'NumCompaniesWorked', 'PerformanceRating', 'RelationshipSatisfaction', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']
# ['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime']

# %%
# Task 3
#getting mean median mode of categorical values
def info_cat(c):
    for i in range(len(c)):
        print(f"Unique values in {c[i]} are :{df[c[i]].unique()}")
        print(f'The Mode of the col {c[i]} is  {df[c[i]].mode()[0]}')
        print(f'The Null values of the col {c[i]} is  {df[c[i]].isnull().sum()}')
        print()
        
info_cat(categorical)
# Out:
# Unique values in Attrition are :['Yes' 'No']
# The Mode of the col Attrition is  No
# The Null values of the col Attrition is  0
#
# Unique values in BusinessTravel are :['Travel_Rarely' 'Travel_Frequently' 'Non-Travel' nan]
# The Mode of the col BusinessTravel is  Travel_Rarely
# The Null values of the col BusinessTravel is  30
#
# Unique values in Department are :['Sales' 'Research & Development' 'Human Resources' nan]
# The Mode of the col Department is  Research & Development
# The Null values of the col Department is  4
#
# Unique values in EducationField are :['Life Sciences' 'Other' 'Medical' 'Marketing' nan 'Technical Degree'
#  'Human Resources']
# The Mode of the col EducationField is  Life Sciences
# The Null values of the col EducationField is  12
#
# Unique values in Gender are :['Female' 'Male' nan]
# The Mode of the col Gender is  Male
# The Null values of the col Gender is  45
#
# ...

# %%
# dropping  null values from categorical values
df.dropna(subset=categorical,inplace=True)
info_cat(categorical)
# Out:
# Unique values in Attrition are :['Yes' 'No']
# The Mode of the col Attrition is  No
# The Null values of the col Attrition is  0
#
# Unique values in BusinessTravel are :['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# The Mode of the col BusinessTravel is  Travel_Rarely
# The Null values of the col BusinessTravel is  0
#
# Unique values in Department are :['Sales' 'Research & Development' 'Human Resources']
# The Mode of the col Department is  Research & Development
# The Null values of the col Department is  0
#
# Unique values in EducationField are :['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# The Mode of the col EducationField is  Life Sciences
# The Null values of the col EducationField is  0
#
# Unique values in Gender are :['Female' 'Male']
# The Mode of the col Gender is  Male
# The Null values of the col Gender is  0
#
# Unique values in JobRole are :['Sales Executive' 'Research Scientist' 'Laboratory Technician'
# ...

# %%
#task 4
# using count plot
for i in range(len(categorical)):
    print(categorical[i])
    plt.figure(figsize=(12,4))
    plt.subplot(121)
    sb.countplot(x=categorical[i],data=df)

    plt.subplot(122)
    per=df[categorical[i]].value_counts()
    l=df[categorical[i]].unique()
    plt.pie(per,labels=l,autopct='%.2f%%')
    plt.show()
    print()
# Out:
# Attrition
# BusinessTravel
# Department
# EducationField
# Gender
# JobRole
# MaritalStatus
# Over18
# OverTime

# %%
# Task 5
#getting mean median mode of categorical values
def info_num(c):
    for i in range(len(c)):
        print(c[i])
        print(f'The Mean is : {df[c[i]].mean()}')
        print(f'The Median is : {df[c[i]].median()}')
        print(f'The STD is : {df[c[i]].std()}')
        print(f'The Null count is : {df[c[i]].isnull().sum()}')
        
        print()

info_num(numerical)
# Out:
# Age
# The Mean is : 36.99599358974359
# The Median is : 36.0
# The STD is : 9.154776228891759
# The Null count is : 21
#
# DistanceFromHome
# The Mean is : 9.290780141843971
# The Median is : 7.0
# The STD is : 8.189961835325304
# The Null count is : 0
#
# EmployeeNumber
# The Mean is : 1024.4357762017337
# The Median is : 1014.0
# The STD is : 602.9432150021768
# The Null count is : 0
#
# EnvironmentSatisfaction
# The Mean is : 2.7257683215130024
# The Median is : 3.0
# The STD is : 1.097231738909111
# The Null count is : 0
#
# HourlyRate
# The Mean is : 65.9826635145784
# The Median is : 66.0
# The STD is : 20.49778049455439
# The Null count is : 0
#
# JobInvolvement
# The Mean is : 2.722616233254531
# The Median is : 3.0
# The STD is : 0.7172727627420462
# The Null count is : 0
#
# JobSatisfaction
# The Mean is : 2.715524034672971
# The Median is : 3.0
# The STD is : 1.1057293354088458
# The Null count is : 0
#
# MonthlyIncome
# The Mean is : 6521.519306540583
# ...

# %%
for i in range(len(numerical)):
    df[numerical[i]]=df[numerical[i]].fillna(value=df[numerical[i]].mean())


info_num(numerical)
# Out:
# Age
# The Mean is : 36.99599358974359
# The Median is : 36.0
# The STD is : 9.078651248510052
# The Null count is : 0
#
# DistanceFromHome
# The Mean is : 9.290780141843971
# The Median is : 7.0
# The STD is : 8.189961835325304
# The Null count is : 0
#
# EmployeeNumber
# The Mean is : 1024.4357762017337
# The Median is : 1014.0
# The STD is : 602.9432150021768
# The Null count is : 0
#
# EnvironmentSatisfaction
# The Mean is : 2.7257683215130024
# The Median is : 3.0
# The STD is : 1.097231738909111
# The Null count is : 0
#
# HourlyRate
# The Mean is : 65.9826635145784
# The Median is : 66.0
# The STD is : 20.49778049455439
# The Null count is : 0
#
# JobInvolvement
# The Mean is : 2.722616233254531
# The Median is : 3.0
# The STD is : 0.7172727627420462
# The Null count is : 0
#
# JobSatisfaction
# The Mean is : 2.715524034672971
# The Median is : 3.0
# The STD is : 1.1057293354088458
# The Null count is : 0
#
# MonthlyIncome
# The Mean is : 6521.519306540583
# ...

# %%
# Task 6
l=['MonthlyIncome','HourlyRate','Age']
for i in range(len(l)):
    print(l[i])
    plt.figure(figsize=(12,4))
    plt.subplot(121)
    sb.histplot(df[l[i]])

    plt.subplot(122)
    sb.boxplot(df[l[i]])
    plt.show()
# Out:
# MonthlyIncome
# HourlyRate
# Age
